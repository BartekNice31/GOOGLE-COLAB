# %% [markdown]
# <a href="https://colab.research.google.com/github/BartekNice31/GOOGLE-COLAB/blob/main/biblioteka_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint

# %%
x=np.linspace(0,20,100)
y=np.random.randn(100,4)
y=np.cumsum(y,axis=0)

# %%
plt.plot(x,y)

# %%
sns.set()
plt.plot(x,y)

# %%
df1=sns.load_dataset('tips')
pprint(df1.head())
pprint(type(df1))
pprint(df1.shape)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>
# (244, 7)

# %%
pprint(df1.describe())
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
pprint(df1.info())

# %%
pprint(df1.describe(include='category'))

# %%
sns.relplot(data=df1,x='tip',y='total_bill')
plt.plot()
plt.show();

# %%
sns.relplot(data=df1,x='total_bill',y='tip')

# %%
sns.regplot(data=df1,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set?

# %%
sns.set_theme?

# %%
sns.set_theme(style='darkgrid',palette="Spectral",font_scale=1)
sns.relplot(data=df1,x='total_bill',y='tip')
